# %%
# !pip install langchain
# !pip install langchain_community
# !pip install faiss-cpu
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.0/974.0 kB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.7/314.7 kB 10.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.9/124.9 kB 16.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 10.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 3.5 MB/s eta 0:00:00
# ...

# %%
# !pip install docx2txt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3960 sha256=0722a81c4b6505fab0736ff07f427aedec223331b277d3a96d556b2dcbc7c51f
#   Stored in directory: /root/.cache/pip/wheels/22/58/cf/093d0a6c3ecfdfc5f6ddd5524043b88e59a9a199cb02352966
# Successfully built docx2txt
# ...

# %%
from langchain_community.document_loaders import DirectoryLoader,PyPDFLoader,TextLoader,CSVLoader,Docx2txtLoader

# %%
# !unzip x.zip
# Out:
# Archive:  x.zip
#    creating: docx folder/
#   inflating: docx folder/Access Control Policy.docx
#   inflating: docx folder/Cyber Regulatory Compliance Policy.docx
#   inflating: docx folder/Encryption Policy for Cyber Assets.docx
#   inflating: docx folder/Environmental Cyber Security Policy.docx
#   inflating: docx folder/Network Security Policy.docx
#   inflating: docx folder/New Microsoft Word Document.docx
#   inflating: docx folder/Password Policy.docx
#   inflating: docx folder/Patch Management Policy.docx
#   inflating: docx folder/Physical Cyber Security Policy.docx
#   inflating: docx folder/User Awareness Policy.docx
#   inflating: docx folder/.~lock.Access Control Policy.docx#

# %%
docs_loader= DirectoryLoader(rf"/content/docx folder",glob='**/*.docx',loader_cls=Docx2txtLoader)

# %%
docs=docs_loader.load()

# %%
from langchain.text_splitter import CharacterTextSplitter

# %%
text_splitter = CharacterTextSplitter(chunk_size=512, chunk_overlap=0)
texts_chunks = text_splitter.split_documents(docs)

# %%
from langchain_community.vectorstores import FAISS

# %%
# !pip install gpt4all
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.8/29.8 MB 37.0 MB/s eta 0:00:00
# ...

# %%
from langchain_community.embeddings import HuggingFaceBgeEmbeddings,OpenAIEmbeddings,OpenAIEmbeddings,HuggingFaceEmbeddings,BedrockEmbeddings,AzureOpenAIEmbeddings,OllamaEmbeddings,HuggingFaceInstructEmbeddings,GPT4AllEmbeddings
embeddings=GPT4AllEmbeddings(model_name="all-MiniLM-L6-v2.gguf2.f16.gguf")
# Out:
# Downloading: 100%|██████████| 45.9M/45.9M [00:00<00:00, 102MiB/s]
# Verifying: 100%|██████████| 45.9M/45.9M [00:00<00:00, 547MiB/s]

# %%
db = FAISS.from_documents(texts_chunks, embeddings)

# %%
# !curl -fsSL https://ollama.com/install.sh | sh

# %%
# !pip install accelerate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 2.6 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
# !pip install optimum
# !pip install auto-gptq
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 418.4/418.4 kB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 12.4 MB/s eta 0:00:00
# ...

# %%
from langchain.llms import HuggingFacePipeline
from transformers import AutoModelForCausalLM, AutoTokenizer, GenerationConfig, pipeline

model_name = "TheBloke/Llama-2-13b-Chat-GPTQ"

model = AutoModelForCausalLM.from_pretrained(model_name,
                                             device_map="auto",
                                             trust_remote_code=True)

tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=True)

gen_cfg = GenerationConfig.from_pretrained(model_name)
gen_cfg.max_new_tokens=512
gen_cfg.temperature=0.0000001 # 0.0
gen_cfg.return_full_text=True
gen_cfg.do_sample=True
gen_cfg.repetition_penalty=1.11

pipe=pipeline(
    task="text-generation",
    model=model,
    tokenizer=tokenizer,
    generation_config=gen_cfg
)

llm = HuggingFacePipeline(pipeline=pipe)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# WARNING:auto_gptq.nn_modules.qlinear.qlinear_cuda:CUDA extension not installed.
# WARNING:auto_gptq.nn_modules.qlinear.qlinear_cuda_old:CUDA extension not installed.
# model.safetensors:   0%|          | 0.00/7.26G [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:4481: FutureWarning: `_is_quantized_training_enabled` is going to be deprecated in transformers 4.39.0. Please use `model.hf_quantizer.is_trainable` instead
# ...

# %%
from langchain.chains.question_answering import load_qa_chain

# %%
prefix = "You are a helpful chatbot and answer questions based on provided context only. If the answer to the question is not there in the context, you can politely say that you do not have the answer"

EXAMPLES=["""Use the following format:

Question: the input question you must answer
Thought: you should always think about what to do
Action: the action to take, should be based on {context}
Action Input: the input to the action
Observation: the result of the action
... (this Thought/Action/Action Input/Observation can repeat N times)
Thought: I now know the final answer
Final Answer: the final answer to the original input question"""]


suffix = """
Context: {context}
User: {query}
AI:
"""
from langchain import HuggingFacePipeline, PromptTemplate

CHAT_PROMPT = PromptTemplate.from_examples(
    examples = EXAMPLES, suffix=suffix, input_variables=["context","query"],prefix=prefix
)

# %%
chain_type_kwargs={"prompt": CHAT_PROMPT}

# %%
chain=load_qa_chain(llm, chain_type="stuff",**chain_type_kwargs)

# %%
llm

# %%
# !pip install langchain

# %%
query="what is password poloicy"
docs = db.similarity_search(query,k=3)

# %%
docs
# Out:
# [Document(page_content='By adhering to this password policy, we aim to enhance the security posture of our organization and safeguard our sensitive data from unauthorized access or breaches.', metadata={'source': '/content/docx folder/Password Policy.docx'}),
#  Document(page_content='Password Policy\n\nPassword Complexity:\n\nPasswords must be at least 12 characters long.\n\nPasswords must contain a combination of at least three of the following character types:\n\nUppercase letters (A-Z)\n\nLowercase letters (a-z)\n\nNumerals (0-9)\n\nSpecial characters (!, @, #, $, %, etc.)\n\nPassword Expiry:\n\nUsers must change their passwords every 90 days.\n\nUsers cannot reuse their last 5 passwords.\n\nAccount Lockout:\n\nAfter 5 consecutive failed login attempts, the account will be locked for 15 minutes.', metadata={'source': '/content/docx folder/Password Policy.docx'}),
# ...

# %%
answer = chain.run(input_documents=docs,query=f"{query}")

# %%
answer
